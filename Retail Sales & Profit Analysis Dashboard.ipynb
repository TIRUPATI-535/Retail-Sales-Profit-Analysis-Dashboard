# %%
import pandas as pd

# %%
dataset=pd.read_csv("RetailDataset.csv")
dataset
# Out:
#        Product     Category  Customer     Region        Date  Quantity  \
# 0      Printer  Electronics  Cust_440     Canada  18-03-2023         8
# 1      Printer       Office  Cust_480     Canada  01-08-2024         4
# 2          NaN  Electronics  Cust_205         UK  22-10-2024         8
# 3      Monitor  Electronics  Cust_336         UK  21-08-2023         5
# 4      Monitor  Accessories  Cust_440     Canada  17-10-2022         4
# ...        ...          ...       ...        ...         ...       ...
# 4995  Keyboard  Accessories  Cust_336     Canada  23-10-2024         4
# 4996     Mouse  Electronics  Cust_420        USA  12-01-2022         5
# 4997    Tablet       Office  Cust_265  Australia  01-05-2024         9
# 4998  Keyboard  Electronics   Cust_84  Australia  18-02-2023         5
# 4999   Monitor  Electronics   Cust_51         UK  03-03-2024         8
#
#       Unit Price  Discount    Cost    Sales
# 0            733      0.17  1153.0  4867.12
# ...

# %%
dataset.head(5)
# Out:
#    Product     Category  Customer  Region        Date  Quantity  Unit Price  \
# 0  Printer  Electronics  Cust_440  Canada  18-03-2023         8         733
# 1  Printer       Office  Cust_480  Canada  01-08-2024         4        1998
# 2      NaN  Electronics  Cust_205      UK  22-10-2024         8        1470
# 3  Monitor  Electronics  Cust_336      UK  21-08-2023         5         214
# 4  Monitor  Accessories  Cust_440  Canada  17-10-2022         4         213
#
#    Discount    Cost    Sales
# 0      0.17  1153.0  4867.12
# 1      0.29   499.0  5674.32
# 2      0.22  1040.0  9172.80
# 3      0.08   753.0   984.40
# 4      0.01   637.0   843.48

# %%
dataset.tail(5)
# Out:
#        Product     Category  Customer     Region        Date  Quantity  \
# 4995  Keyboard  Accessories  Cust_336     Canada  23-10-2024         4
# 4996     Mouse  Electronics  Cust_420        USA  12-01-2022         5
# 4997    Tablet       Office  Cust_265  Australia  01-05-2024         9
# 4998  Keyboard  Electronics   Cust_84  Australia  18-02-2023         5
# 4999   Monitor  Electronics   Cust_51         UK  03-03-2024         8
#
#       Unit Price  Discount    Cost    Sales
# 4995        1321      0.08    82.0  4861.28
# 4996         994      0.13   318.0  4323.90
# 4997         712      0.21   623.0  5062.32
# 4998        1669      0.17   479.0  6926.35
# 4999         950      0.17  1091.0  6308.00

# %%
dataset.describe(include='all')
# Out:
#         Product     Category  Customer   Region        Date     Quantity  \
# count      4904         5000      5000     5000        5000  5000.000000
# unique        8            3       500        6        1085          NaN
# top     Printer  Accessories  Cust_480  Germany  27-01-2023          NaN
# freq        644         1692        19      878          15          NaN
# mean        NaN          NaN       NaN      NaN         NaN     4.954800
# std         NaN          NaN       NaN      NaN         NaN     2.554068
# min         NaN          NaN       NaN      NaN         NaN     1.000000
# 25%         NaN          NaN       NaN      NaN         NaN     3.000000
# 50%         NaN          NaN       NaN      NaN         NaN     5.000000
# 75%         NaN          NaN       NaN      NaN         NaN     7.000000
# max         NaN          NaN       NaN      NaN         NaN     9.000000
#
#          Unit Price     Discount         Cost          Sales
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Product     4904 non-null   object
#  1   Category    5000 non-null   object
#  2   Customer    5000 non-null   object
#  3   Region      5000 non-null   object
#  4   Date        5000 non-null   object
#  5   Quantity    5000 non-null   int64
#  6   Unit Price  5000 non-null   int64
#  7   Discount    4900 non-null   float64
#  8   Cost        4898 non-null   float64
#  9   Sales       5000 non-null   float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 390.8+ KB

# %%
dataset.shape
# Out:
# (5000, 10)

# %%
dataset.columns
# Out:
# Index(['Product', 'Category', 'Customer', 'Region', 'Date', 'Quantity',
#        'Unit Price', 'Discount', 'Cost', 'Sales'],
#       dtype='object')

# %%
dataset.dtypes
# Out:
# Product        object
# Category       object
# Customer       object
# Region         object
# Date           object
# Quantity        int64
# Unit Price      int64
# Discount      float64
# Cost          float64
# Sales         float64
# dtype: object

# %%
dataset.columns=dataset.columns.str.strip()
dataset.columns
# Out:
# Index(['Product', 'Category', 'Customer', 'Region', 'Date', 'Quantity',
#        'Unit Price', 'Discount', 'Cost', 'Sales'],
#       dtype='object')

# %%
dataset.isnull().sum()
# Out:
# Product        96
# Category        0
# Customer        0
# Region          0
# Date            0
# Quantity        0
# Unit Price      0
# Discount      100
# Cost          102
# Sales           0
# dtype: int64

# %%
dataset.dropna(subset=['Product','Cost'], inplace=True)

# %%
dataset['Discount']=dataset['Discount'].fillna(0)
dataset['Discount']
# Out:
# 0       0.17
# 1       0.29
# 3       0.08
# 4       0.01
# 5       0.25
#         ...
# 4995    0.08
# 4996    0.13
# 4997    0.21
# 4998    0.17
# 4999    0.17
# Name: Discount, Length: 4803, dtype: float64

# %%
dataset.isnull().sum()
# Out:
# Product       0
# Category      0
# Customer      0
# Region        0
# Date          0
# Quantity      0
# Unit Price    0
# Discount      0
# Cost          0
# Sales         0
# dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# np.int64(90)

# %%
# it actually shows the duplicate values
dataset[dataset.duplicated()]
# Out:
#          Product     Category  Customer     Region        Date  Quantity  \
# 478   Headphones  Electronics  Cust_232     Canada  30-10-2024         3
# 612     Keyboard       Office    Cust_9  Australia  09-01-2023         8
# 843        Mouse       Office  Cust_393     Canada  03-01-2024         9
# 927      Printer  Electronics  Cust_140  Australia  31-05-2023         6
# 986     Keyboard  Electronics  Cust_366         UK  24-07-2023         3
# ...          ...          ...       ...        ...         ...       ...
# 4890  Headphones       Office  Cust_452      India  09-04-2023         4
# 4896     Printer  Accessories  Cust_395         UK  14-07-2024         4
# 4925      Tablet  Electronics  Cust_249      India  05-12-2022         8
# 4935    Keyboard       Office  Cust_287     Canada  26-12-2024         7
# 4985  Headphones       Office  Cust_154    Germany  19-01-2022         1
#
#       Unit Price  Discount    Cost     Sales
# 478         1578      0.09   118.0   4307.94
# ...

# %%
dataset.drop_duplicates(inplace=True)

# %%
dataset.shape
# Out:
# (4713, 10)

# %%
clean=dataset.rename(columns={'Cost':'Produ_Cost'})
clean
# Reminder dictionary
# Out:
#          Product     Category  Customer     Region        Date  Quantity  \
# 0        Printer  Electronics  Cust_440     Canada  18-03-2023         8
# 1        Printer       Office  Cust_480     Canada  01-08-2024         4
# 3        Monitor  Electronics  Cust_336         UK  21-08-2023         5
# 4        Monitor  Accessories  Cust_440     Canada  17-10-2022         4
# 5     Headphones  Accessories  Cust_138     Canada  10-01-2023         7
# ...          ...          ...       ...        ...         ...       ...
# 4995    Keyboard  Accessories  Cust_336     Canada  23-10-2024         4
# 4996       Mouse  Electronics  Cust_420        USA  12-01-2022         5
# 4997      Tablet       Office  Cust_265  Australia  01-05-2024         9
# 4998    Keyboard  Electronics   Cust_84  Australia  18-02-2023         5
# 4999     Monitor  Electronics   Cust_51         UK  03-03-2024         8
#
#       Unit Price  Discount  Produ_Cost    Sales
# ...

# %%
dataset.sort_values('Sales',ascending=False)
# Out:
#          Product     Category  Customer     Region        Date  Quantity  \
# 858      Monitor  Accessories  Cust_474    Germany  12-01-2022         9
# 4003      Laptop  Electronics   Cust_53        USA  15-03-2022         7
# 3885       Mouse       Office  Cust_416      India  07-04-2024         7
# 4320      Tablet  Electronics  Cust_329         UK  25-06-2022         7
# 3610     Monitor  Accessories  Cust_232        USA  09-07-2024         9
# ...          ...          ...       ...        ...         ...       ...
# 1157     Printer       Office  Cust_402         UK  29-11-2024         1
# 1125  Headphones  Accessories  Cust_173  Australia  27-06-2023         1
# 48         Mouse  Electronics  Cust_369         UK  25-05-2023         1
# 3028       Phone       Office  Cust_456     Canada  28-03-2022         1
# 2441       Phone  Accessories   Cust_93  Australia  20-01-2022         1
#
#       Unit Price  Discount    Cost      Sales
# ...

# %%
dataset['Customer'].value_counts()
# Out:
# Customer
# Cust_281    18
# Cust_271    17
# Cust_235    17
# Cust_480    17
# Cust_77     16
#             ..
# Cust_124     4
# Cust_117     3
# Cust_97      3
# Cust_36      3
# Cust_14      2
# Name: count, Length: 500, dtype: int64

# %%
dataset['Region'].unique()
# Out:
# array(['Canada', 'UK', 'USA', 'Germany', 'Australia', 'India'],
#       dtype=object)

# %%
dataset['Region'].nunique()
# Out:
# 6

# %%
dataset.query('Sales>100000')
# Out:
#       Product     Category  Customer   Region        Date  Quantity  \
# 858   Monitor  Accessories  Cust_474  Germany  12-01-2022         9
# 3610  Monitor  Accessories  Cust_232      USA  09-07-2024         9
# 3885    Mouse       Office  Cust_416    India  07-04-2024         7
# 4003   Laptop  Electronics   Cust_53      USA  15-03-2022         7
# 4320   Tablet  Electronics  Cust_329       UK  25-06-2022         7
#
#       Unit Price  Discount    Cost     Sales
# 858         1882      0.04   761.0  162604.8
# 3610        1217      0.07   497.0  101862.9
# 3885        1696      0.02   694.0  116345.6
# 4003        1935      0.14  1268.0  116487.0
# 4320        1774      0.00   950.0  115487.4

# %%
pd.pivot_table(dataset,values='Sales',index='Region',aggfunc='sum')
# Out:
#                 Sales
# Region
# Australia  3650380.00
# Canada     3555734.70
# Germany    4030712.96
# India      3834840.28
# UK         3547774.58
# USA        3731854.71

# %%
dataset_clean = (
    dataset
   .query("Sales > 100000 and Region == 'UK'")
    .assign(Product=lambda x: x["Product"].str.upper())
    .sort_values("Sales", ascending=False)
)
dataset_clean
# Out:
#      Product     Category  Customer Region        Date  Quantity  Unit Price  \
# 4320  TABLET  Electronics  Cust_329     UK  25-06-2022         7        1774
#
#       Discount   Cost     Sales
# 4320       0.0  950.0  115487.4

# %%
data_Clean=dataset.assign (
    
    Profit=lambda x: x["Sales"] - x["Cost"]
)
data_Clean
# Out:
#          Product     Category  Customer     Region        Date  Quantity  \
# 0        Printer  Electronics  Cust_440     Canada  18-03-2023         8
# 1        Printer       Office  Cust_480     Canada  01-08-2024         4
# 3        Monitor  Electronics  Cust_336         UK  21-08-2023         5
# 4        Monitor  Accessories  Cust_440     Canada  17-10-2022         4
# 5     Headphones  Accessories  Cust_138     Canada  10-01-2023         7
# ...          ...          ...       ...        ...         ...       ...
# 4995    Keyboard  Accessories  Cust_336     Canada  23-10-2024         4
# 4996       Mouse  Electronics  Cust_420        USA  12-01-2022         5
# 4997      Tablet       Office  Cust_265  Australia  01-05-2024         9
# 4998    Keyboard  Electronics   Cust_84  Australia  18-02-2023         5
# 4999     Monitor  Electronics   Cust_51         UK  03-03-2024         8
#
#       Unit Price  Discount    Cost    Sales   Profit
# ...

# %%
dataset["Region_Avg_Sales"] = dataset.groupby("Region")["Sales"].transform("mean")
dataset["Region_Avg_Sales"]
# Out:
# 0       4395.222126
# 1       4395.222126
# 3       4736.681682
# 4       4395.222126
# 5       4395.222126
#            ...
# 4995    4395.222126
# 4996    4741.873837
# 4997    4644.249364
# 4998    4644.249364
# 4999    4736.681682
# Name: Region_Avg_Sales, Length: 4713, dtype: float64

# %%
dataset
# Out:
#          Product     Category  Customer     Region        Date  Quantity  \
# 0        Printer  Electronics  Cust_440     Canada  18-03-2023         8
# 1        Printer       Office  Cust_480     Canada  01-08-2024         4
# 3        Monitor  Electronics  Cust_336         UK  21-08-2023         5
# 4        Monitor  Accessories  Cust_440     Canada  17-10-2022         4
# 5     Headphones  Accessories  Cust_138     Canada  10-01-2023         7
# ...          ...          ...       ...        ...         ...       ...
# 4995    Keyboard  Accessories  Cust_336     Canada  23-10-2024         4
# 4996       Mouse  Electronics  Cust_420        USA  12-01-2022         5
# 4997      Tablet       Office  Cust_265  Australia  01-05-2024         9
# 4998    Keyboard  Electronics   Cust_84  Australia  18-02-2023         5
# 4999     Monitor  Electronics   Cust_51         UK  03-03-2024         8
#
#       Unit Price  Discount    Cost    Sales  Region_Avg_Sales
# ...

# %%
dataset["Sales_Level"] = pd.qcut(dataset["Sales"], q=4,
                             labels=["Low","Medium","High","Very High"])
dataset["Sales_Level"]
# Out:
# 0            High
# 1            High
# 3             Low
# 4             Low
# 5       Very High
#           ...
# 4995         High
# 4996         High
# 4997         High
# 4998    Very High
# 4999         High
# Name: Sales_Level, Length: 4713, dtype: category
# Categories (4, object): ['Low' < 'Medium' < 'High' < 'Very High']

# %%
dataset
# Out:
#          Product     Category  Customer     Region        Date  Quantity  \
# 0        Printer  Electronics  Cust_440     Canada  18-03-2023         8
# 1        Printer       Office  Cust_480     Canada  01-08-2024         4
# 3        Monitor  Electronics  Cust_336         UK  21-08-2023         5
# 4        Monitor  Accessories  Cust_440     Canada  17-10-2022         4
# 5     Headphones  Accessories  Cust_138     Canada  10-01-2023         7
# ...          ...          ...       ...        ...         ...       ...
# 4995    Keyboard  Accessories  Cust_336     Canada  23-10-2024         4
# 4996       Mouse  Electronics  Cust_420        USA  12-01-2022         5
# 4997      Tablet       Office  Cust_265  Australia  01-05-2024         9
# 4998    Keyboard  Electronics   Cust_84  Australia  18-02-2023         5
# 4999     Monitor  Electronics   Cust_51         UK  03-03-2024         8
#
#       Unit Price  Discount    Cost    Sales  Region_Avg_Sales Sales_Level
# ...

# %%
dataset[(dataset["Sales"] > 100000) & (dataset["Region"] == "India")]
# Out:
#      Product Category  Customer Region        Date  Quantity  Unit Price  \
# 3885   Mouse   Office  Cust_416  India  07-04-2024         7        1696
#
#       Discount   Cost     Sales  Region_Avg_Sales Sales_Level
# 3885      0.02  694.0  116345.6       5059.156042   Very High

# %%
data_replace=dataset['Customer'].str.replace("Cust_","Customer")
data_replace
# Out:
# 0       Customer440
# 1       Customer480
# 3       Customer336
# 4       Customer440
# 5       Customer138
#            ...
# 4995    Customer336
# 4996    Customer420
# 4997    Customer265
# 4998     Customer84
# 4999     Customer51
# Name: Customer, Length: 4713, dtype: object

# %%
avg_revenue = dataset.groupby("Product")["Sales"].agg(["mean","sum","max"])
print(avg_revenue)
# Out:
#                    mean         sum       max
# Product
# Headphones  4532.157053  2583329.52   58664.4
# Keyboard    4640.283678  2737767.37   59392.0
# Laptop      5037.781142  3088159.84  116487.0
# Monitor     4832.701466  2967278.70  162604.8
# Mouse       5114.606324  2838606.51  116345.6
# Phone       4717.600565  2755078.73   76944.0
# Printer     4332.108685  2668578.95   27936.0
# Tablet      4750.433643  2712497.61  115487.4

# %%
dataset.loc[0]
# Out:
# Product                 Printer
# Category            Electronics
# Customer               Cust_440
# Region                   Canada
# Date                 18-03-2023
# Quantity                      8
# Unit Price                  733
# Discount                   0.17
# Cost                     1153.0
# Sales                   4867.12
# Region_Avg_Sales    4395.222126
# Sales_Level                High
# Name: 0, dtype: object

# %%
dataset
# Out:
#          Product     Category  Customer     Region        Date  Quantity  \
# 0        Printer  Electronics  Cust_440     Canada  18-03-2023         8
# 1        Printer       Office  Cust_480     Canada  01-08-2024         4
# 3        Monitor  Electronics  Cust_336         UK  21-08-2023         5
# 4        Monitor  Accessories  Cust_440     Canada  17-10-2022         4
# 5     Headphones  Accessories  Cust_138     Canada  10-01-2023         7
# ...          ...          ...       ...        ...         ...       ...
# 4995    Keyboard  Accessories  Cust_336     Canada  23-10-2024         4
# 4996       Mouse  Electronics  Cust_420        USA  12-01-2022         5
# 4997      Tablet       Office  Cust_265  Australia  01-05-2024         9
# 4998    Keyboard  Electronics   Cust_84  Australia  18-02-2023         5
# 4999     Monitor  Electronics   Cust_51         UK  03-03-2024         8
#
#       Unit Price  Discount    Cost    Sales  Region_Avg_Sales Sales_Level
# ...

# %%
dataset['Profit']=dataset["Sales"]- dataset["Cost"]
dataset['Profit']
# Out:
# 0       3714.12
# 1       5175.32
# 3        231.40
# 4        206.48
# 5       8559.75
#          ...
# 4995    4779.28
# 4996    4005.90
# 4997    4439.32
# 4998    6447.35
# 4999    5217.00
# Name: Profit, Length: 4713, dtype: float64

# %%
dataset
# Out:
#          Product     Category  Customer     Region        Date  Quantity  \
# 0        Printer  Electronics  Cust_440     Canada  18-03-2023         8
# 1        Printer       Office  Cust_480     Canada  01-08-2024         4
# 3        Monitor  Electronics  Cust_336         UK  21-08-2023         5
# 4        Monitor  Accessories  Cust_440     Canada  17-10-2022         4
# 5     Headphones  Accessories  Cust_138     Canada  10-01-2023         7
# ...          ...          ...       ...        ...         ...       ...
# 4995    Keyboard  Accessories  Cust_336     Canada  23-10-2024         4
# 4996       Mouse  Electronics  Cust_420        USA  12-01-2022         5
# 4997      Tablet       Office  Cust_265  Australia  01-05-2024         9
# 4998    Keyboard  Electronics   Cust_84  Australia  18-02-2023         5
# 4999     Monitor  Electronics   Cust_51         UK  03-03-2024         8
#
#       Unit Price  Discount    Cost    Sales  Region_Avg_Sales Sales_Level  \
# ...

# %%
dataset["Profit_Margin"]=(dataset["Profit"]/dataset["Sales"])*100
dataset["Profit_Margin"]
# Out:
# 0       76.310426
# 1       91.205995
# 3       23.506705
# 4       24.479537
# 5       93.114139
#           ...
# 4995    98.313201
# 4996    92.645528
# 4997    87.693390
# 4998    93.084381
# 4999    82.704502
# Name: Profit_Margin, Length: 4713, dtype: float64

# %%
dataset
# Out:
#          Product     Category  Customer     Region        Date  Quantity  \
# 0        Printer  Electronics  Cust_440     Canada  18-03-2023         8
# 1        Printer       Office  Cust_480     Canada  01-08-2024         4
# 3        Monitor  Electronics  Cust_336         UK  21-08-2023         5
# 4        Monitor  Accessories  Cust_440     Canada  17-10-2022         4
# 5     Headphones  Accessories  Cust_138     Canada  10-01-2023         7
# ...          ...          ...       ...        ...         ...       ...
# 4995    Keyboard  Accessories  Cust_336     Canada  23-10-2024         4
# 4996       Mouse  Electronics  Cust_420        USA  12-01-2022         5
# 4997      Tablet       Office  Cust_265  Australia  01-05-2024         9
# 4998    Keyboard  Electronics   Cust_84  Australia  18-02-2023         5
# 4999     Monitor  Electronics   Cust_51         UK  03-03-2024         8
#
#       Unit Price  Discount    Cost    Sales  Region_Avg_Sales Sales_Level  \
# ...

# %%
dataset["Total_Discount"]=dataset["Quantity"]*dataset["Unit Price"]*dataset["Discount"]
dataset["Total_Discount"]
# Out:
# 0        996.88
# 1       2317.68
# 3         85.60
# 4          8.52
# 5       3064.25
#          ...
# 4995     422.72
# 4996     646.10
# 4997    1345.68
# 4998    1418.65
# 4999    1292.00
# Name: Total_Discount, Length: 4713, dtype: float64

# %%
dataset
# Out:
#          Product     Category  Customer     Region        Date  Quantity  \
# 0        Printer  Electronics  Cust_440     Canada  18-03-2023         8
# 1        Printer       Office  Cust_480     Canada  01-08-2024         4
# 3        Monitor  Electronics  Cust_336         UK  21-08-2023         5
# 4        Monitor  Accessories  Cust_440     Canada  17-10-2022         4
# 5     Headphones  Accessories  Cust_138     Canada  10-01-2023         7
# ...          ...          ...       ...        ...         ...       ...
# 4995    Keyboard  Accessories  Cust_336     Canada  23-10-2024         4
# 4996       Mouse  Electronics  Cust_420        USA  12-01-2022         5
# 4997      Tablet       Office  Cust_265  Australia  01-05-2024         9
# 4998    Keyboard  Electronics   Cust_84  Australia  18-02-2023         5
# 4999     Monitor  Electronics   Cust_51         UK  03-03-2024         8
#
#       Unit Price  Discount    Cost    Sales  Region_Avg_Sales Sales_Level  \
# ...

# %%
# Total revenue and profit of the each Region
Region_wise=dataset.groupby("Region")[["Sales","Profit"]].sum()
Region_wise
# Out:
#                 Sales      Profit
# Region
# Australia  3650380.00  3054088.00
# Canada     3555734.70  2926495.70
# Germany    4030712.96  3397016.96
# India      3834840.28  3257565.28
# UK         3547774.58  2980757.58
# USA        3731854.71  3125402.71

# %%
high_margin = dataset[dataset['Profit_Margin'] > 20]
high_margin
# Out:
#          Product     Category  Customer     Region        Date  Quantity  \
# 0        Printer  Electronics  Cust_440     Canada  18-03-2023         8
# 1        Printer       Office  Cust_480     Canada  01-08-2024         4
# 3        Monitor  Electronics  Cust_336         UK  21-08-2023         5
# 4        Monitor  Accessories  Cust_440     Canada  17-10-2022         4
# 5     Headphones  Accessories  Cust_138     Canada  10-01-2023         7
# ...          ...          ...       ...        ...         ...       ...
# 4995    Keyboard  Accessories  Cust_336     Canada  23-10-2024         4
# 4996       Mouse  Electronics  Cust_420        USA  12-01-2022         5
# 4997      Tablet       Office  Cust_265  Australia  01-05-2024         9
# 4998    Keyboard  Electronics   Cust_84  Australia  18-02-2023         5
# 4999     Monitor  Electronics   Cust_51         UK  03-03-2024         8
#
#       Unit Price  Discount    Cost    Sales  Region_Avg_Sales Sales_Level  \
# ...

# %%
low_margin = dataset[dataset['Profit_Margin'] < 10]
low_margin
# Out:
#       Product     Category  Customer     Region        Date  Quantity  \
# 15     Tablet       Office   Cust_29         UK  14-09-2023         2
# 16     Laptop  Electronics  Cust_289        USA  11-03-2023         2
# 18      Phone  Accessories  Cust_382  Australia  16-05-2022         7
# 30      Phone       Office  Cust_175     Canada  12-12-2022         3
# 48      Mouse  Electronics  Cust_369         UK  25-05-2023         1
# ...       ...          ...       ...        ...         ...       ...
# 4960   Laptop       Office   Cust_10    Germany  22-08-2023         3
# 4971   Laptop  Electronics  Cust_279         UK  23-10-2022         2
# 4972   Tablet  Accessories  Cust_189         UK  13-12-2023         3
# 4973   Laptop  Accessories   Cust_16     Canada  09-01-2022         2
# 4988  Monitor  Accessories  Cust_393        USA  06-08-2022         6
#
#       Unit Price  Discount    Cost    Sales  Region_Avg_Sales Sales_Level  \
# ...

# %%
dataset
# Out:
#          Product     Category  Customer     Region        Date  Quantity  \
# 0        Printer  Electronics  Cust_440     Canada  18-03-2023         8
# 1        Printer       Office  Cust_480     Canada  01-08-2024         4
# 3        Monitor  Electronics  Cust_336         UK  21-08-2023         5
# 4        Monitor  Accessories  Cust_440     Canada  17-10-2022         4
# 5     Headphones  Accessories  Cust_138     Canada  10-01-2023         7
# ...          ...          ...       ...        ...         ...       ...
# 4995    Keyboard  Accessories  Cust_336     Canada  23-10-2024         4
# 4996       Mouse  Electronics  Cust_420        USA  12-01-2022         5
# 4997      Tablet       Office  Cust_265  Australia  01-05-2024         9
# 4998    Keyboard  Electronics   Cust_84  Australia  18-02-2023         5
# 4999     Monitor  Electronics   Cust_51         UK  03-03-2024         8
#
#       Unit Price  Discount    Cost    Sales  Region_Avg_Sales Sales_Level  \
# ...

# %%
from sqlalchemy import create_engine

engine= create_engine(
    "mssql+pyodbc://@TIRUPATI\\SQLEXPRESS/Retail?driver=ODBC+Driver+18+for+SQL+Server&trusted_connection=yes&TrustServerCertificate=yes"
)
dataset.to_sql("Retail_Data", engine, if_exists="replace", index=False)

print("successfully data Loaded")
# Out:
# successfully data Loaded

# %%
dataset.shape
# Out:
# (4713, 15)

# %%
print(type(dataset))
print(dataset.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['Product', 'Category', 'Customer', 'Region', 'Date', 'Quantity',
#        'Unit Price', 'Discount', 'Cost', 'Sales', 'Region_Avg_Sales',
#        'Sales_Level', 'Profit', 'Profit_Margin', 'Total_Discount'],
#       dtype='object')
